# %%
import sys

# %%
class Car:
    def __init__(self, make, model, miles):
        self.make = make
        self.model = model
        self.miles = miles
        self.is_on = False
    def honk(self): 
        print("BEEEEP!!")
    def start(self):
        self.is_on = True
    def
    def drive(self, dist):
        self.miles += dist

# %%
mycar = Car('Ford', 'Focus', 0)

# %%
mycar.make
# Out:
# 'Ford'

# %%
mycar.model
# Out:
# 'Focus'

# %%
mycar.miles
# Out:
# 0

# %%
mycar.honk()
# Out:
# BEEEEP!!

# %%
mycar.miles
# Out:
# 0

# %%
mycar.drive(100)

# %%
mycar.miles
# Out:
# 100

# %%
# !pip install ccxt
# Out:
# ...
#     100% |████████████████████████████████| 1.0MB 2.0MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 153kB 805kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 604kB 1.7MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 163kB 1.8MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 133kB 1.9MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 225kB 1.9MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 245kB 1.9MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 71kB 2.5MB/s ta 0:00:011
# ...
#     100% |████████████████████████████████| 7.3MB 1.3MB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for yarl ... done
#   Stored in directory: /Users/ericeuler/Library/Caches/pip/wheels/96/26/b9/7972042a1a69556ba7f38b8a301dc3a9ddac1b8f61f02fbfd8
#   Running setup.py bdist_wheel for pycares ... done
#   Stored in directory: /Users/ericeuler/Library/Caches/pip/wheels/1b/05/16/da47eb345e8f05adee9145e6e0d0e2a30813af6b677afe9eff
# ...

# %%
import ccxt

# %%
conn = ccxt.kraken()

# %%
conn.fetchTickers()
# Out:
# {'BCH/EUR': {'symbol': 'BCH/EUR',
#   'timestamp': 1536621117489,
#   'datetime': '2018-09-10T23:11:57.489Z',
#   'high': 422.3,
#   'low': 392.2,
#   'bid': 400.6,
#   'bidVolume': None,
#   'ask': 401.6,
#   'askVolume': None,
#   'vwap': 406.903684,
#   'open': 414.1,
#   'close': 399.0,
#   'last': 399.0,
#   'previousClose': None,
#   'change': None,
#   'percentage': None,
#   'average': None,
#   'baseVolume': 1877.28212514,
#   'quoteVolume': 763873.012626815,
#   'info': {'a': ['401.600000', '1', '1.000'],
#    'b': ['400.600000', '11', '11.000'],
#    'c': ['399.000000', '0.10000000'],
#    'v': ['1862.29851745', '1877.28212514'],
#    'p': ['406.838632', '406.903684'],
#    't': [1151, 1173],
#    'l': ['392.200000', '392.200000'],
#    'h': ['422.300000', '422.300000'],
#    'o': '414.100000'}},
#  'BCH/USD': {'symbol': 'BCH/USD',
#   'timestamp': 1536621117489,
#   'datetime': '2018-09-10T23:11:57.489Z',
#   'high': 487.0,
#   'low': 459.0,
#   'bid': 464.6,
# ...

# %%
def get_price(curr):
    conn.fetchTickers()[f'{curr}/USD']['last']

# %%
get_price('BTC')
